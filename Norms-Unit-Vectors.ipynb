# %%
import numpy as np

# in here we will be using the L**2 norm

x = np.array([25,  2,  5])
print((25**2 + 2**2 + 5**2)**(1/2))
print(np.linalg.norm(x))
# Out:
# 25.573423705088842
# 25.573423705088842

# %%
import numpy as np

# in here we will be using the L**1 norm

x = np.array([25,  2,  5])
print(np.max([np.abs(25), np.abs(2), np.abs(5)]))
# Out:
# 25
